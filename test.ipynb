# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('./Lecture21_data/small_diamonds.csv')

# %%
sns.pairplot(data)
# Out:
# c:\Users\minta\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
